# %% [markdown]
# # Generate tax features

# %% [markdown]
# ### Introduction

# %% [markdown]
# This notebook documents the process of generating feature data from the file matched_Fire_Incidents.csv. These features will be used as the target variables in modeling.

# %% [markdown]
# ### Load libraries and CSV

# %%
import numpy as np
import pandas as pd
from datetime import datetime

path = 'C:\\Users\\Kevin\\Desktop\\Fire Risk\\Model_matched_to_EAS'

#This will take a while to load.  Very large file...
tax_df = pd.read_csv(path + '\\' + 'matched_EAS_Tax_Data.csv', 
              low_memory=False)[[
                 'EAS BaseID',
                 'Neighborhoods - Analysis Boundaries',
                 'Property Class Code',
                 'Property_Class_Code_Desc',
                 'Location_y',
                 'Address',
                 'Year Property Built',
                 'Number of Bathrooms',
                 'Number of Bedrooms',
                 'Number of Rooms',
                 'Number of Stories',
                 'Number of Units',
                 'Percent of Ownership',
                 'Closed Roll Assessed Land Value',
                 'Property Area in Square Feet',
                 'Closed Roll Assessed Improvement Value'
                 ]].dropna()

#Create land value per square foot var
tax_df['landval_psqft'] = tax_df['Closed Roll Assessed Land Value'] / tax_df['Property Area in Square Feet']

tax_df.rename(columns = {'EAS BaseID': 'EAS'}, inplace=True)
tax_df.rename(columns = {'Neighborhoods - Analysis Boundaries': 'Neighborhood'}, inplace=True)

# %%
tax_df.head()
# Out:
#       EAS                    Neighborhood Property Class Code  \
# 0  467876  Financial District/South Beach                   Z
# 1  467876  Financial District/South Beach                   Z
# 2  467876  Financial District/South Beach                   Z
# 3  467876  Financial District/South Beach                   Z
# 4  467876  Financial District/South Beach                   Z
#
#   Property_Class_Code_Desc                             Location_y  \
# 0              Condominium  (37.7862904935788, -122.401375196262)
# 1              Condominium  (37.7862904935788, -122.401375196262)
# 2              Condominium  (37.7862904935788, -122.401375196262)
# 3              Condominium  (37.7862904935788, -122.401375196262)
# 4              Condominium  (37.7862904935788, -122.401375196262)
#
#         Address  Year Property Built  Number of Bathrooms  Number of Bedrooms  \
# 0  188 MINNA ST               2005.0                  2.0                   2
# 1  188 MINNA ST               2005.0                  2.0                   2
# 2  188 MINNA ST               2005.0                  2.0                   2
# 3  188 MINNA ST               2005.0                  2.0                   2
# 4  188 MINNA ST               2005.0                  2.0                   2
#
#    Number of Rooms  Number of Stories  Number of Units  Percent of Ownership  \
# 0                5                  0                0                  1.00
# 1                5                  0                0                  1.00
# 2                5                  0                0                  1.00
# 3                5                  0                0                  1.00
# 4                5                  0                0                  0.75
#
#    Closed Roll Assessed Land Value  Property Area in Square Feet  \
# 0                        1140725.0                          1670
# 1                        1168821.0                          1670
# 2                        1118358.0                          1670
# 3                        1110000.0                          1670
# 4                         837521.0                          1670
#
#    Closed Roll Assessed Improvement Value  landval_psqft
# 0                                760483.0     683.068862
# 1                                779213.0     699.892814
# 2                                745572.0     669.675449
# 3                                740000.0     664.670659
# 4                                837521.0     501.509581

# %% [markdown]
# ### Remove outlier observations, then collapse by EAS

# %%
def removal(var, low, high):
    tax_df[(tax_df[var]<=low) & (tax_df[var]<=high)]
    return tax_df

#Remove if 0 stories, remove if > 30 stories
tax_df = removal('Number of Stories',1,30)

#Remove if landvalue/sq_foot = 1 or > 1000
tax_df = removal('landval_psqft',1,1000)

#Remove if num. bathrooms, bedrooms, extra rooms > 100
tax_df = removal('Number of Bathrooms',0,100)
tax_df = removal('Number of Bedrooms',0,100)
tax_df = removal('Number of Rooms',0,100)

#Remove if year_built < 1880 or > 2017
tax_df = removal('Year Property Built',1880,2017)

#Remove num units > 250
tax_df = removal('Number of Units',0,250)

#Remove percent ownership < 0, > 1
tax_df = removal('Percent of Ownership',0,1)

#Create Tot_rooms var
tax_df['Tot_Rooms'] = tax_df['Number of Bathrooms'] + \
                    tax_df['Number of Bedrooms']  + \
                    tax_df['Number of Rooms']
        
#Subset to numeric vars only, group by EAS average          
tax_df_num = tax_df[[
                 'EAS',
                 'Year Property Built',
                 'Number of Bathrooms',
                 'Number of Bedrooms',
                 'Number of Rooms',
                 'Number of Stories',
                 'Number of Units',
                 'Percent of Ownership',
                 'Closed Roll Assessed Land Value',
                 'Property Area in Square Feet',
                 'Closed Roll Assessed Improvement Value',
                 'Tot_Rooms',
                 'landval_psqft'
                 ]].groupby(by='EAS').mean().reset_index()

# %%
pd.options.display.float_format = '{:.2f}'.format
tax_df_num.describe()
# Out:
#             EAS  Year Property Built  Number of Bathrooms  Number of Bedrooms  \
# count 182644.00            182644.00            182644.00           182644.00
# mean  374906.74              1929.35                 1.00                1.00
# std    58990.87                25.00                 2.42                2.42
# min   274493.00              1880.00                 0.00                0.00
# 25%   324300.75              1908.00                 0.00                0.00
# 50%   373653.50              1925.00                 0.00                0.00
# 75%   421535.25              1945.00                 1.33                1.33
# max   490644.00              2016.00                80.00               80.00
#
#        Number of Rooms  Number of Stories  Number of Units  \
# count        182644.00          182644.00        182644.00
# mean             10.71               1.79             2.47
# std              10.70               1.05             5.20
# min               0.00               1.00             0.00
# 25%               5.00               1.00             1.00
# 50%               7.00               2.00             1.00
# 75%              12.00               2.00             1.89
# max              99.00              30.00           193.00
#
#        Percent of Ownership  Closed Roll Assessed Land Value  \
# count             182644.00                        182644.00
# mean                   0.87                        435003.43
# std                    0.23                       1865870.60
# min                    0.00                          1902.00
# 25%                    0.78                         78906.33
# 50%                    1.00                        224573.61
# 75%                    1.00                        444255.47
# max                    1.00                     140883380.88
#
#        Property Area in Square Feet  Closed Roll Assessed Improvement Value  \
# count                     182644.00                               182644.00
# mean                        4226.29                               419898.65
# std                        16384.31                              2805331.13
# min                          100.00                                    0.00
# 25%                         1325.00                               101625.12
# 50%                         2000.00                               198820.14
# 75%                         3484.00                               354569.88
# max                      1320000.00                            323993523.44
#
#        Tot_Rooms  landval_psqft
# count  182644.00      182644.00
# mean       12.72         143.15
# std        12.43         140.32
# min         0.00           1.03
# 25%         6.00          30.07
# 50%         9.00          98.60
# 75%        15.00         212.30
# max       205.00         994.22

# %% [markdown]
# ### Create subset of string vars

# %%
tax_df_str = tax_df[[
                 'EAS',
                 'Neighborhood',
                 'Property Class Code',
                 'Property_Class_Code_Desc',
                 'Location_y',
                 'Address',
                 ]].groupby(by='EAS').max().reset_index()

tax_df_str['Property_Class_Code_Desc'] = tax_df_str['Property_Class_Code_Desc'].apply(lambda x: x.upper())
tax_df_str['Neighborhood'] = tax_df_str['Neighborhood'].apply(lambda x: x.upper())

# %%
tax_df_str.head()
# Out:
#       EAS  Neighborhood Property Class Code     Property_Class_Code_Desc  \
# 0  274493  RUSSIAN HILL                   A                    APARTMENT
# 1  274494  RUSSIAN HILL                  AC  APARTMNT & COMMERCIAL STORE
# 2  274503  RUSSIAN HILL                   A                    APARTMENT
# 3  274504   NORTH BEACH                  F2                 FLAT & STORE
# 4  274505   NORTH BEACH                   A                    APARTMENT
#
#                               Location_y          Address
# 0  (37.8064516469645, -122.420784953602)     2761 HYDE ST
# 1  (37.8050093143699, -122.420019737303)     2606 HYDE ST
# 2  (37.8041055728047, -122.416472710727)    2436 JONES ST
# 3   (37.8045548007939, -122.41310730589)    2262 MASON ST
# 4  (37.8042828119518, -122.410214408196)  404 CHESTNUT ST

# %% [markdown]
# ### Create more generalized grouping for Property Class

# %%
pd.set_option("display.max_rows",999)
tax_df_str.groupby(['Property Class Code', 'Property_Class_Code_Desc']).count()
# Out:
#                                                                 EAS  \
# Property Class Code Property_Class_Code_Desc
# A                   APARTMENT                                 22085
# AC                  APARTMNT & COMMERCIAL STORE                1051
# B                   BANK                                        126
# C                   COMMERCIAL STORES                          4402
# C1                  SHOPPING CENTER                              14
# CD                  COMMERCIAL STORES                            10
# CM                  COMMERCIAL/MIXED USE                         27
# CO                  COOP UNITS UNSEGREGATED                      27
# COS                 COOP UNITS SEGREGATED                         4
#                     COOP UNITS UNSEGREGATED                      23
# CP                  CITY PROPERTY                                 5
# CZ                  COMMERCIAL STORE CONDO                      253
#                     COMMERCIAL STORES                            10
# D                   DWELLING                                  95387
# DA                  DWELLINGS - APARTMENTS                      501
# DBM                 DWELLING BMR                                 97
# DD                  2 DWELLINGS ON ONE PARCEL                   121
#                     APARTMENT                                    14
#                     DWELLING                                     76
#                     DWELLINGS - APARTMENTS                        3
# DF                  1 FLAT & DWELLING-1 PARCEL                   26
#                     DWELLING                                     14
# E                   SCHOOLS                                      97
# EC                  ENTERTAINMENT COMPLEX                         4
# F                   FLATS & DUPLEX                            33728
#                     SCHOOLS                                       2
# F2                  FLAT & STORE                               5975
#                     FLATS & DUPLEX                               99
# FA                  1 FLAT & 1 APT BLDG-1 PARCEL                 63
#                     APARTMENT                                    14
#                     DWELLING                                     13
#                     FLATS & DUPLEX                               23
# G                   GARAGES (COMMERCIAL)                        219
# GC                  GOLF COURSE                                   1
#                     SCHOOLS                                       1
# GZ                  GARAGE CONDOMINIUM                            2
# H                   HOTEL                                         4
# H1                  HOTEL                                        21
# H2                  HOTELS - OTHER                              849
# HC                  HOTEL COMMERCIAL (H2W/COM)                   59
#                     HOTELS - OTHER                                5
# I                   INDUSTRIAL                                 1977
#                     SCHOOLS                                       1
# IDC                 INDUSTRIAL DATA CENTER                        7
# IW                  INDUSTIAL WAREHOUSE                         145
#                     SHOPPING CENTER                               1
# IX                  INDUSTRIAL MIXED/OTHER USE                    7
# IZ                  INDUSTRIAL CONDOMINIUM                       20
# LZ                  LIVE/WORK CONDOMINIUM                       155
# M                   MOTELS                                       75
# MB                  MISSION BAY                                   1
# MIX                 MIXED USE                                    14
# N1                  HOSPITALS                                    13
# N2                  CONVALESCENT/NURSING HOMES                   67
#                     DWELLING                                      6
#                     FLATS & DUPLEX                                5
#                     HOTEL                                         1
#                     HOTELS - OTHER                                9
# O                   OFFICE                                     1877
#                     SCHOOLS                                       6
# OA                  OFFICE AND APARTMENTS                        31
# OAH                 OFFICE - HIGH CLASS A                         2
# OBH                 OFFICE - HIGH CLASS B                         5
# OBM                 OFFICE - MIDDLE CLASS B                       4
# OC                  OFFICE WITH MAJOR RETAIL UNITS               51
# OCH                 OFFICE - HIGH CLASS C                         9
# OCL                 OFFICE - LOW CLASS C                         14
# OCM                 OFFICE - MIDDLE CLASS C                       2
# OMD                 MEDICAL- DENTAL OFFICE BUILDING               7
#                     OFFICE                                       10
# OZ                  OFFICE - CONDOMINIUM                         26
# P                   PUBLIC BUILDINGS (GOVT)                       3
# PD                  PUD (PLANNED UNIT DEVELOPMENT)              183
# PL                  PARKING LOT                                   5
# PZ                  PARKING STALL CONDOMINIUM                     1
# RH                  RESIDENTIAL HOTEL & SRO                     288
# RH1                 RETAIL & HOTEL                               42
# S                   GAS STATION                                  92
# T                   THEATRES                                     56
# TH                  TOWN HOUSE                                  144
# TIA                 TI APARTMENT                                576
# TIF                 TI FLATS & DUPLEX                           432
# TSU                 TIME SHARE UNSEGREGATED                      10
# U                   CLUBS,LODGES,FRATERNAL ORGANIZATIONS        102
#                     COMMERCIAL STORES                             5
#                     FLAT & STORE                                  1
#                     HOTELS - OTHER                                2
#                     LIVE/WORK CONDOMINIUM                         2
# V                   VACANT LOT                                   84
# VR                  VACANT LOT - RESTRICTIONS                    55
# W                   CHURCHES,CONVENTS,RECTORIES                 355
#                     COMMERCIAL STORES                             1
#                     COMMERCIAL/MIXED USE                          1
#                     CONVALESCENT/NURSING HOMES                    1
#                     DWELLING                                      4
#                     FLAT & STORE                                  1
#                     INDUSTIAL WAREHOUSE                           4
#                     INDUSTRIAL MIXED/OTHER USE                    4
#                     OFFICE                                        1
#                     RESIDENTIAL HOTEL & SRO                       1
#                     SCHOOLS                                       4
#                     SHOPPING CENTER                               2
#                     VACANT LOT - RESTRICTIONS                    12
# X                   MISC                                        219
#                     OFFICE                                        4
#                     PARKING STALL CONDOMINIUM                     2
#                     SCHOOLS                                       3
#                     THEATRES                                      3
#                     VACANT LOT                                    2
#                     VACANT LOT - RESTRICTIONS                     1
# XV                  SINGLE STRUCT ON MULTI LOT(D & F'S ONLY)      9
# Z                   CONDOMINIUM                                9225
#                     COOP UNITS UNSEGREGATED                       1
#                     DWELLING                                     21
#                     FLAT & STORE                                 14
#                     FLATS & DUPLEX                              216
#                     GARAGES (COMMERCIAL)                          3
#                     INDUSTRIAL                                    7
#                     INDUSTRIAL CONDOMINIUM                        7
#                     LIVE/WORK CONDOMINIUM                        28
#                     MISC                                          3
#                     OFFICE - CONDOMINIUM                         13
#                     PARKING LOT                                   2
#                     PARKING STALL CONDOMINIUM                     1
#                     TI APARTMENT                                 53
#                     TI FLATS & DUPLEX                            46
#                     TIME SHARE UNSEGREGATED                       1
#                     TOWN HOUSE                                   29
#                     VACANT LOT                                    1
#                     VACANT LOT - RESTRICTIONS                     3
# ZBM                 CONDOMINIUM BMR                             236
#                     DWELLING                                      1
#                     DWELLING BMR                                  1
#                     GARAGE CONDOMINIUM                            2
#                     GARAGES (COMMERCIAL)                          1
#                     INDUSTRIAL                                    3
#                     LIVE/WORK CONDOMINIUM                         3
#                     MISC                                          1
#                     OFFICE - CONDOMINIUM                          2
#
#                                                               Neighborhood  \
# Property Class Code Property_Class_Code_Desc
# A                   APARTMENT                                        22085
# AC                  APARTMNT & COMMERCIAL STORE                       1051
# B                   BANK                                               126
# C                   COMMERCIAL STORES                                 4402
# C1                  SHOPPING CENTER                                     14
# CD                  COMMERCIAL STORES                                   10
# CM                  COMMERCIAL/MIXED USE                                27
# CO                  COOP UNITS UNSEGREGATED                             27
# COS                 COOP UNITS SEGREGATED                                4
#                     COOP UNITS UNSEGREGATED                             23
# CP                  CITY PROPERTY                                        5
# CZ                  COMMERCIAL STORE CONDO                             253
#                     COMMERCIAL STORES                                   10
# D                   DWELLING                                         95387
# DA                  DWELLINGS - APARTMENTS                             501
# DBM                 DWELLING BMR                                        97
# DD                  2 DWELLINGS ON ONE PARCEL                          121
#                     APARTMENT                                           14
#                     DWELLING                                            76
#                     DWELLINGS - APARTMENTS                               3
# DF                  1 FLAT & DWELLING-1 PARCEL                          26
#                     DWELLING                                            14
# E                   SCHOOLS                                             97
# EC                  ENTERTAINMENT COMPLEX                                4
# F                   FLATS & DUPLEX                                   33728
#                     SCHOOLS                                              2
# F2                  FLAT & STORE                                      5975
#                     FLATS & DUPLEX                                      99
# FA                  1 FLAT & 1 APT BLDG-1 PARCEL                        63
#                     APARTMENT                                           14
#                     DWELLING                                            13
#                     FLATS & DUPLEX                                      23
# G                   GARAGES (COMMERCIAL)                               219
# GC                  GOLF COURSE                                          1
#                     SCHOOLS                                              1
# GZ                  GARAGE CONDOMINIUM                                   2
# H                   HOTEL                                                4
# H1                  HOTEL                                               21
# H2                  HOTELS - OTHER                                     849
# HC                  HOTEL COMMERCIAL (H2W/COM)                          59
#                     HOTELS - OTHER                                       5
# I                   INDUSTRIAL                                        1977
#                     SCHOOLS                                              1
# IDC                 INDUSTRIAL DATA CENTER                               7
# IW                  INDUSTIAL WAREHOUSE                                145
#                     SHOPPING CENTER                                      1
# IX                  INDUSTRIAL MIXED/OTHER USE                           7
# IZ                  INDUSTRIAL CONDOMINIUM                              20
# LZ                  LIVE/WORK CONDOMINIUM                              155
# M                   MOTELS                                              75
# MB                  MISSION BAY                                          1
# MIX                 MIXED USE                                           14
# N1                  HOSPITALS                                           13
# N2                  CONVALESCENT/NURSING HOMES                          67
#                     DWELLING                                             6
#                     FLATS & DUPLEX                                       5
#                     HOTEL                                                1
#                     HOTELS - OTHER                                       9
# O                   OFFICE                                            1877
#                     SCHOOLS                                              6
# OA                  OFFICE AND APARTMENTS                               31
# OAH                 OFFICE - HIGH CLASS A                                2
# OBH                 OFFICE - HIGH CLASS B                                5
# OBM                 OFFICE - MIDDLE CLASS B                              4
# OC                  OFFICE WITH MAJOR RETAIL UNITS                      51
# OCH                 OFFICE - HIGH CLASS C                                9
# OCL                 OFFICE - LOW CLASS C                                14
# OCM                 OFFICE - MIDDLE CLASS C                              2
# OMD                 MEDICAL- DENTAL OFFICE BUILDING                      7
#                     OFFICE                                              10
# OZ                  OFFICE - CONDOMINIUM                                26
# P                   PUBLIC BUILDINGS (GOVT)                              3
# PD                  PUD (PLANNED UNIT DEVELOPMENT)                     183
# PL                  PARKING LOT                                          5
# PZ                  PARKING STALL CONDOMINIUM                            1
# RH                  RESIDENTIAL HOTEL & SRO                            288
# RH1                 RETAIL & HOTEL                                      42
# S                   GAS STATION                                         92
# T                   THEATRES                                            56
# TH                  TOWN HOUSE                                         144
# TIA                 TI APARTMENT                                       576
# TIF                 TI FLATS & DUPLEX                                  432
# TSU                 TIME SHARE UNSEGREGATED                             10
# U                   CLUBS,LODGES,FRATERNAL ORGANIZATIONS               102
#                     COMMERCIAL STORES                                    5
#                     FLAT & STORE                                         1
#                     HOTELS - OTHER                                       2
#                     LIVE/WORK CONDOMINIUM                                2
# V                   VACANT LOT                                          84
# VR                  VACANT LOT - RESTRICTIONS                           55
# W                   CHURCHES,CONVENTS,RECTORIES                        355
#                     COMMERCIAL STORES                                    1
#                     COMMERCIAL/MIXED USE                                 1
#                     CONVALESCENT/NURSING HOMES                           1
#                     DWELLING                                             4
#                     FLAT & STORE                                         1
#                     INDUSTIAL WAREHOUSE                                  4
#                     INDUSTRIAL MIXED/OTHER USE                           4
#                     OFFICE                                               1
#                     RESIDENTIAL HOTEL & SRO                              1
#                     SCHOOLS                                              4
#                     SHOPPING CENTER                                      2
#                     VACANT LOT - RESTRICTIONS                           12
# X                   MISC                                               219
#                     OFFICE                                               4
#                     PARKING STALL CONDOMINIUM                            2
#                     SCHOOLS                                              3
#                     THEATRES                                             3
#                     VACANT LOT                                           2
#                     VACANT LOT - RESTRICTIONS                            1
# XV                  SINGLE STRUCT ON MULTI LOT(D & F'S ONLY)             9
# Z                   CONDOMINIUM                                       9225
#                     COOP UNITS UNSEGREGATED                              1
#                     DWELLING                                            21
#                     FLAT & STORE                                        14
#                     FLATS & DUPLEX                                     216
#                     GARAGES (COMMERCIAL)                                 3
#                     INDUSTRIAL                                           7
#                     INDUSTRIAL CONDOMINIUM                               7
#                     LIVE/WORK CONDOMINIUM                               28
#                     MISC                                                 3
#                     OFFICE - CONDOMINIUM                                13
#                     PARKING LOT                                          2
#                     PARKING STALL CONDOMINIUM                            1
#                     TI APARTMENT                                        53
#                     TI FLATS & DUPLEX                                   46
#                     TIME SHARE UNSEGREGATED                              1
#                     TOWN HOUSE                                          29
#                     VACANT LOT                                           1
#                     VACANT LOT - RESTRICTIONS                            3
# ZBM                 CONDOMINIUM BMR                                    236
#                     DWELLING                                             1
#                     DWELLING BMR                                         1
#                     GARAGE CONDOMINIUM                                   2
#                     GARAGES (COMMERCIAL)                                 1
#                     INDUSTRIAL                                           3
#                     LIVE/WORK CONDOMINIUM                                3
#                     MISC                                                 1
#                     OFFICE - CONDOMINIUM                                 2
#
#                                                               Location_y  \
# Property Class Code Property_Class_Code_Desc
# A                   APARTMENT                                      22085
# AC                  APARTMNT & COMMERCIAL STORE                     1051
# B                   BANK                                             126
# C                   COMMERCIAL STORES                               4402
# C1                  SHOPPING CENTER                                   14
# CD                  COMMERCIAL STORES                                 10
# CM                  COMMERCIAL/MIXED USE                              27
# CO                  COOP UNITS UNSEGREGATED                           27
# COS                 COOP UNITS SEGREGATED                              4
#                     COOP UNITS UNSEGREGATED                           23
# CP                  CITY PROPERTY                                      5
# CZ                  COMMERCIAL STORE CONDO                           253
#                     COMMERCIAL STORES                                 10
# D                   DWELLING                                       95387
# DA                  DWELLINGS - APARTMENTS                           501
# DBM                 DWELLING BMR                                      97
# DD                  2 DWELLINGS ON ONE PARCEL                        121
#                     APARTMENT                                         14
#                     DWELLING                                          76
#                     DWELLINGS - APARTMENTS                             3
# DF                  1 FLAT & DWELLING-1 PARCEL                        26
#                     DWELLING                                          14
# E                   SCHOOLS                                           97
# EC                  ENTERTAINMENT COMPLEX                              4
# F                   FLATS & DUPLEX                                 33728
#                     SCHOOLS                                            2
# F2                  FLAT & STORE                                    5975
#                     FLATS & DUPLEX                                    99
# FA                  1 FLAT & 1 APT BLDG-1 PARCEL                      63
#                     APARTMENT                                         14
#                     DWELLING                                          13
#                     FLATS & DUPLEX                                    23
# G                   GARAGES (COMMERCIAL)                             219
# GC                  GOLF COURSE                                        1
#                     SCHOOLS                                            1
# GZ                  GARAGE CONDOMINIUM                                 2
# H                   HOTEL                                              4
# H1                  HOTEL                                             21
# H2                  HOTELS - OTHER                                   849
# HC                  HOTEL COMMERCIAL (H2W/COM)                        59
#                     HOTELS - OTHER                                     5
# I                   INDUSTRIAL                                      1977
#                     SCHOOLS                                            1
# IDC                 INDUSTRIAL DATA CENTER                             7
# IW                  INDUSTIAL WAREHOUSE                              145
#                     SHOPPING CENTER                                    1
# IX                  INDUSTRIAL MIXED/OTHER USE                         7
# IZ                  INDUSTRIAL CONDOMINIUM                            20
# LZ                  LIVE/WORK CONDOMINIUM                            155
# M                   MOTELS                                            75
# MB                  MISSION BAY                                        1
# MIX                 MIXED USE                                         14
# N1                  HOSPITALS                                         13
# N2                  CONVALESCENT/NURSING HOMES                        67
#                     DWELLING                                           6
#                     FLATS & DUPLEX                                     5
#                     HOTEL                                              1
#                     HOTELS - OTHER                                     9
# O                   OFFICE                                          1877
#                     SCHOOLS                                            6
# OA                  OFFICE AND APARTMENTS                             31
# OAH                 OFFICE - HIGH CLASS A                              2
# OBH                 OFFICE - HIGH CLASS B                              5
# OBM                 OFFICE - MIDDLE CLASS B                            4
# OC                  OFFICE WITH MAJOR RETAIL UNITS                    51
# OCH                 OFFICE - HIGH CLASS C                              9
# OCL                 OFFICE - LOW CLASS C                              14
# OCM                 OFFICE - MIDDLE CLASS C                            2
# OMD                 MEDICAL- DENTAL OFFICE BUILDING                    7
#                     OFFICE                                            10
# OZ                  OFFICE - CONDOMINIUM                              26
# P                   PUBLIC BUILDINGS (GOVT)                            3
# PD                  PUD (PLANNED UNIT DEVELOPMENT)                   183
# PL                  PARKING LOT                                        5
# PZ                  PARKING STALL CONDOMINIUM                          1
# RH                  RESIDENTIAL HOTEL & SRO                          288
# RH1                 RETAIL & HOTEL                                    42
# S                   GAS STATION                                       92
# T                   THEATRES                                          56
# TH                  TOWN HOUSE                                       144
# TIA                 TI APARTMENT                                     576
# TIF                 TI FLATS & DUPLEX                                432
# TSU                 TIME SHARE UNSEGREGATED                           10
# U                   CLUBS,LODGES,FRATERNAL ORGANIZATIONS             102
#                     COMMERCIAL STORES                                  5
#                     FLAT & STORE                                       1
#                     HOTELS - OTHER                                     2
#                     LIVE/WORK CONDOMINIUM                              2
# V                   VACANT LOT                                        84
# VR                  VACANT LOT - RESTRICTIONS                         55
# W                   CHURCHES,CONVENTS,RECTORIES                      355
#                     COMMERCIAL STORES                                  1
#                     COMMERCIAL/MIXED USE                               1
#                     CONVALESCENT/NURSING HOMES                         1
#                     DWELLING                                           4
#                     FLAT & STORE                                       1
#                     INDUSTIAL WAREHOUSE                                4
#                     INDUSTRIAL MIXED/OTHER USE                         4
#                     OFFICE                                             1
#                     RESIDENTIAL HOTEL & SRO                            1
#                     SCHOOLS                                            4
#                     SHOPPING CENTER                                    2
#                     VACANT LOT - RESTRICTIONS                         12
# X                   MISC                                             219
#                     OFFICE                                             4
#                     PARKING STALL CONDOMINIUM                          2
#                     SCHOOLS                                            3
#                     THEATRES                                           3
#                     VACANT LOT                                         2
#                     VACANT LOT - RESTRICTIONS                          1
# XV                  SINGLE STRUCT ON MULTI LOT(D & F'S ONLY)           9
# Z                   CONDOMINIUM                                     9225
#                     COOP UNITS UNSEGREGATED                            1
#                     DWELLING                                          21
#                     FLAT & STORE                                      14
#                     FLATS & DUPLEX                                   216
#                     GARAGES (COMMERCIAL)                               3
#                     INDUSTRIAL                                         7
#                     INDUSTRIAL CONDOMINIUM                             7
#                     LIVE/WORK CONDOMINIUM                             28
#                     MISC                                               3
#                     OFFICE - CONDOMINIUM                              13
#                     PARKING LOT                                        2
#                     PARKING STALL CONDOMINIUM                          1
#                     TI APARTMENT                                      53
#                     TI FLATS & DUPLEX                                 46
#                     TIME SHARE UNSEGREGATED                            1
#                     TOWN HOUSE                                        29
#                     VACANT LOT                                         1
#                     VACANT LOT - RESTRICTIONS                          3
# ZBM                 CONDOMINIUM BMR                                  236
#                     DWELLING                                           1
#                     DWELLING BMR                                       1
#                     GARAGE CONDOMINIUM                                 2
#                     GARAGES (COMMERCIAL)                               1
#                     INDUSTRIAL                                         3
#                     LIVE/WORK CONDOMINIUM                              3
#                     MISC                                               1
#                     OFFICE - CONDOMINIUM                               2
#
#                                                               Address
# Property Class Code Property_Class_Code_Desc
# A                   APARTMENT                                   22085
# AC                  APARTMNT & COMMERCIAL STORE                  1051
# B                   BANK                                          126
# C                   COMMERCIAL STORES                            4402
# C1                  SHOPPING CENTER                                14
# CD                  COMMERCIAL STORES                              10
# CM                  COMMERCIAL/MIXED USE                           27
# CO                  COOP UNITS UNSEGREGATED                        27
# COS                 COOP UNITS SEGREGATED                           4
#                     COOP UNITS UNSEGREGATED                        23
# CP                  CITY PROPERTY                                   5
# CZ                  COMMERCIAL STORE CONDO                        253
#                     COMMERCIAL STORES                              10
# D                   DWELLING                                    95387
# DA                  DWELLINGS - APARTMENTS                        501
# DBM                 DWELLING BMR                                   97
# DD                  2 DWELLINGS ON ONE PARCEL                     121
#                     APARTMENT                                      14
#                     DWELLING                                       76
#                     DWELLINGS - APARTMENTS                          3
# DF                  1 FLAT & DWELLING-1 PARCEL                     26
#                     DWELLING                                       14
# E                   SCHOOLS                                        97
# EC                  ENTERTAINMENT COMPLEX                           4
# F                   FLATS & DUPLEX                              33728
#                     SCHOOLS                                         2
# F2                  FLAT & STORE                                 5975
#                     FLATS & DUPLEX                                 99
# FA                  1 FLAT & 1 APT BLDG-1 PARCEL                   63
#                     APARTMENT                                      14
#                     DWELLING                                       13
#                     FLATS & DUPLEX                                 23
# G                   GARAGES (COMMERCIAL)                          219
# GC                  GOLF COURSE                                     1
#                     SCHOOLS                                         1
# GZ                  GARAGE CONDOMINIUM                              2
# H                   HOTEL                                           4
# H1                  HOTEL                                          21
# H2                  HOTELS - OTHER                                849
# HC                  HOTEL COMMERCIAL (H2W/COM)                     59
#                     HOTELS - OTHER                                  5
# I                   INDUSTRIAL                                   1977
#                     SCHOOLS                                         1
# IDC                 INDUSTRIAL DATA CENTER                          7
# IW                  INDUSTIAL WAREHOUSE                           145
#                     SHOPPING CENTER                                 1
# IX                  INDUSTRIAL MIXED/OTHER USE                      7
# IZ                  INDUSTRIAL CONDOMINIUM                         20
# LZ                  LIVE/WORK CONDOMINIUM                         155
# M                   MOTELS                                         75
# MB                  MISSION BAY                                     1
# MIX                 MIXED USE                                      14
# N1                  HOSPITALS                                      13
# N2                  CONVALESCENT/NURSING HOMES                     67
#                     DWELLING                                        6
#                     FLATS & DUPLEX                                  5
#                     HOTEL                                           1
#                     HOTELS - OTHER                                  9
# O                   OFFICE                                       1877
#                     SCHOOLS                                         6
# OA                  OFFICE AND APARTMENTS                          31
# OAH                 OFFICE - HIGH CLASS A                           2
# OBH                 OFFICE - HIGH CLASS B                           5
# OBM                 OFFICE - MIDDLE CLASS B                         4
# OC                  OFFICE WITH MAJOR RETAIL UNITS                 51
# OCH                 OFFICE - HIGH CLASS C                           9
# OCL                 OFFICE - LOW CLASS C                           14
# OCM                 OFFICE - MIDDLE CLASS C                         2
# OMD                 MEDICAL- DENTAL OFFICE BUILDING                 7
#                     OFFICE                                         10
# OZ                  OFFICE - CONDOMINIUM                           26
# P                   PUBLIC BUILDINGS (GOVT)                         3
# PD                  PUD (PLANNED UNIT DEVELOPMENT)                183
# PL                  PARKING LOT                                     5
# PZ                  PARKING STALL CONDOMINIUM                       1
# RH                  RESIDENTIAL HOTEL & SRO                       288
# RH1                 RETAIL & HOTEL                                 42
# S                   GAS STATION                                    92
# T                   THEATRES                                       56
# TH                  TOWN HOUSE                                    144
# TIA                 TI APARTMENT                                  576
# TIF                 TI FLATS & DUPLEX                             432
# TSU                 TIME SHARE UNSEGREGATED                        10
# U                   CLUBS,LODGES,FRATERNAL ORGANIZATIONS          102
#                     COMMERCIAL STORES                               5
#                     FLAT & STORE                                    1
#                     HOTELS - OTHER                                  2
#                     LIVE/WORK CONDOMINIUM                           2
# V                   VACANT LOT                                     84
# VR                  VACANT LOT - RESTRICTIONS                      55
# W                   CHURCHES,CONVENTS,RECTORIES                   355
#                     COMMERCIAL STORES                               1
#                     COMMERCIAL/MIXED USE                            1
#                     CONVALESCENT/NURSING HOMES                      1
#                     DWELLING                                        4
#                     FLAT & STORE                                    1
#                     INDUSTIAL WAREHOUSE                             4
#                     INDUSTRIAL MIXED/OTHER USE                      4
#                     OFFICE                                          1
#                     RESIDENTIAL HOTEL & SRO                         1
#                     SCHOOLS                                         4
#                     SHOPPING CENTER                                 2
#                     VACANT LOT - RESTRICTIONS                      12
# X                   MISC                                          219
#                     OFFICE                                          4
#                     PARKING STALL CONDOMINIUM                       2
#                     SCHOOLS                                         3
#                     THEATRES                                        3
#                     VACANT LOT                                      2
#                     VACANT LOT - RESTRICTIONS                       1
# XV                  SINGLE STRUCT ON MULTI LOT(D & F'S ONLY)        9
# Z                   CONDOMINIUM                                  9225
#                     COOP UNITS UNSEGREGATED                         1
#                     DWELLING                                       21
#                     FLAT & STORE                                   14
#                     FLATS & DUPLEX                                216
#                     GARAGES (COMMERCIAL)                            3
#                     INDUSTRIAL                                      7
#                     INDUSTRIAL CONDOMINIUM                          7
#                     LIVE/WORK CONDOMINIUM                          28
#                     MISC                                            3
#                     OFFICE - CONDOMINIUM                           13
#                     PARKING LOT                                     2
#                     PARKING STALL CONDOMINIUM                       1
#                     TI APARTMENT                                   53
#                     TI FLATS & DUPLEX                              46
#                     TIME SHARE UNSEGREGATED                         1
#                     TOWN HOUSE                                     29
#                     VACANT LOT                                      1
#                     VACANT LOT - RESTRICTIONS                       3
# ZBM                 CONDOMINIUM BMR                               236
#                     DWELLING                                        1
#                     DWELLING BMR                                    1
#                     GARAGE CONDOMINIUM                              2
#                     GARAGES (COMMERCIAL)                            1
#                     INDUSTRIAL                                      3
#                     LIVE/WORK CONDOMINIUM                           3
#                     MISC                                            1
#                     OFFICE - CONDOMINIUM                            2

# %% [markdown]
# Somewhat difficult to group.  I think we should seperate some of the large categories, and roll all of the smaller categories into "Other".  For example:
#
# APARTMENTS -  A, AC, DA, TIA
# DWELLING - D
# FLATS AND DUPLEX - F, F2, FA, TIF
# CONDO - Z Condominium
# COMMERCIAL - C, CD, B, C1, CD, CM, CZ
# INDUSTRIAL - I, IDC, IW, IX, IZ
# OFFICE - O, OA, OAH, OBH, OBM, OC, OCH, OCL, OCM, OMD, OZ
# OTHER - All other codes

# %%
di = {'APARTMENT': ['A', 'AC', 'DA', 'TIA'], 
      'DWELLING': ['D'], 
      'FLATS AND DUPLEX': ['F','F2','FA','TIF'], 
      'CONDO, ETC.': ['Z'],
      'COMMERCIAL USE': ['C','CD','B','C1','CD','CM','CZ'],
      'INDUSTRIAL USE': ['I','IDC','IW','IX','IZ'],
      'OFFICE' : ['O', 'OA','OAH', 'OBH', 'OBM', 'OC', 'OCH', 'OCL', 'OCM', 'OMD', 'OZ']}

# reverse the mapping
di = {d:c for c, d_list in di.items()
        for d in d_list}

#Map to 'Building_Cat' groupings var
tax_df_str['Building_Cat'] = tax_df_str['Property Class Code'].map(di)

#Remainders placed in "OTHER" category
x = ['APARTMENT', 'DWELLING', 'FLATS AND DUPLEX', 'CONDO, ETC.', 'COMMERCIAL USE', 'INDUSTRIAL USE', 'OFFICE']
tax_df_str.loc[~tax_df_str['Building_Cat'].isin(x), 'Building_Cat'] = 'OTHER'

# %%
tax_df_str['Building_Cat'].value_counts()
# Out:
# DWELLING            95387
# FLATS AND DUPLEX    40349
# APARTMENT           24213
# CONDO, ETC.          9674
# COMMERCIAL USE       4842
# OTHER                3977
# INDUSTRIAL USE       2158
# OFFICE               2044
# Name: Building_Cat, dtype: int64

# %% [markdown]
# ### Merge DF back, clean up, export

# %%
exp_df = pd.merge(tax_df_str, tax_df_num, how='left', on='EAS')
exp_df.drop(['Property Class Code', 'Property_Class_Code_Desc'], inplace=True, axis=1)

# %%
#Rename
exp_df.rename(columns = {'Year Property Built': 'Yr_Property_Built'}, inplace=True)
exp_df.rename(columns = {'Number of Bathrooms': 'Num_Bathrooms'}, inplace=True)
exp_df.rename(columns = {'Number of Bedrooms': 'Num_Bedrooms'}, inplace=True)
exp_df.rename(columns = {'Number of Rooms': 'Num_Rooms'}, inplace=True)
exp_df.rename(columns = {'Number of Stories': 'Num_Stories'}, inplace=True)
exp_df.rename(columns = {'Number of Units': 'Num_Units'}, inplace=True)
exp_df.rename(columns = {'Percent of Ownership': 'Perc_Ownership'}, inplace=True)
exp_df.rename(columns = {'Closed Roll Assessed Land Value': 'Land_Value'}, inplace=True)
exp_df.rename(columns = {'Property Area in Square Feet': 'Property_Area'}, inplace=True)
exp_df.rename(columns = {'Closed Roll Assessed Improvement Value': 'Assessed_Improvement_Val'}, inplace=True)

# %%
exp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182644 entries, 0 to 182643
# Data columns (total 17 columns):
# EAS                         182644 non-null int64
# Neighborhood                182644 non-null object
# Location_y                  182644 non-null object
# Address                     182644 non-null object
# Building_Cat                182644 non-null object
# Yr_Property_Built           182644 non-null float64
# Num_Bathrooms               182644 non-null float64
# Num_Bedrooms                182644 non-null float64
# Num_Rooms                   182644 non-null float64
# Num_Stories                 182644 non-null float64
# Num_Units                   182644 non-null float64
# Perc_Ownership              182644 non-null float64
# Land_Value                  182644 non-null float64
# Property_Area               182644 non-null float64
# Assessed_Improvement_Val    182644 non-null float64
# Tot_Rooms                   182644 non-null float64
# landval_psqft               182644 non-null float64
# dtypes: float64(12), int64(1), object(4)
# memory usage: 25.1+ MB

# %%
#Export data
exp_df.to_csv(path_or_buf= path + '\\' + 'tax_data_formerge_20170917.csv', index=False)
