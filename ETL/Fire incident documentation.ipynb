# %% [markdown]
# # Generate Fire Incident Features

# %% [markdown]
# ### Introduction

# %% [markdown]
# This notebook documents the process of generating feature data from the file matched_Fire_Incidents.csv.  These features will be used as the target variables in modeling.

# %% [markdown]
# ### Load libraries and CSV

# %%
import numpy as np
import pandas as pd
from datetime import datetime

path = 'C:\\Users\\Kevin\\Desktop\\Fire Risk\\Model_matched_to_EAS'
incident_df = pd.read_csv(path + '\\' + 'matched_Fire_Incidents.csv', 
              low_memory=False)[['Incident Date','Primary Situation','EAS']].dropna()  #Drop obs  where any variable NAN

incident_df['Incident Date'] = pd.to_datetime(incident_df['Incident Date'])
incident_df['Incident_Year'] = incident_df['Incident Date'].dt.year

# %%
incident_df.head()
# Out:
#   Incident Date                             Primary Situation       EAS  \
# 0    2015-06-20       113 cooking fire, confined to container  451005.0
# 1    2006-08-05                           111 - building fire  422528.0
# 2    2005-05-30    151 - outside rubbish, trash or waste fire  489180.0
# 3    2010-11-28     113 - cooking fire, confined to container  360149.0
# 4    2003-10-05  154 - dumpster/outside trash receptacle fire  279186.0
#
#    Incident_Year
# 0           2015
# 1           2006
# 2           2005
# 3           2010
# 4           2003

# %% [markdown]
# ### Create larger incident category groupings

# %%
incident_df['code'] = incident_df['Primary Situation'].apply(lambda s: s[0:3])
pd.set_option("display.max_rows",999)
incident_df.groupby(['Primary Situation', 'code']).count()
# Out:
#                                                          Incident Date   EAS  \
# Primary Situation                                  code
# 1 -                                                1 -              26    26
# 10 -                                               10               30    30
# 100 - fire, other                                  100             721   721
# 100 fire, other                                    100             823   823
# 11 -                                               11                2     2
# 111 - building fire                                111            3770  3770
# 111 building fire                                  111             909   909
# 112 - fires in struct. other than in a bldg.       112             294   294
# 112 fires in structure other than in a building    112              58    58
# 113 - cooking fire, confined to container          113            9540  9540
# 113 cooking fire, confined to container            113            2642  2642
# 114 - chimney/flue fire, confined to chimney       114             132   132
# 114 chimney or flue fire, confined to chimney o... 114              28    28
# 115 - incinerator overload/mal.,fire confined      115              10    10
# 115 incinerator overload or malfunction, fire c... 115               4     4
# 116 - fuel burner/boiler mal., fire coinfined      116              28    28
# 116 fuel burner/boiler malfunction, fire confined  116               5     5
# 117 - commercial compactor fire, rubbish only      117              22    22
# 117 commercial compactor fire, confined to rubbish 117               1     1
# 118 - trash or rubbish fire, contained             118            6070  6070
# 118 trash or rubbish fire, contained               118             585   585
# 120 - fire mob.prop. used as fixed structure       120               4     4
# 120 fire in mobile prop. used as a fixed struc.... 120               3     3
# 121 - fire in mob. home used as residence          121               4     4
# 121 fire in mobile home used as fixed residence    121               1     1
# 122 - fire in motor home, camper or rv             122              25    25
# 122 fire in motor home, camper, recreational ve... 122               3     3
# 123 - fire in portable bldg., fixed location       123              18    18
# 123 fire in portable building, fixed location      123               3     3
# 1230 fire in portable building (port-a-potty)      123              48    48
# 130 - mobile property (vehicle) fire, other        130             455   455
# 130 mobile property (vehicle) fire, other          130             103   103
# 131 - passenger vehicle fire                       131            1587  1587
# 131 passenger vehicle fire                         131             521   521
# 132 - road freight or transport vehicle fire       132              38    38
# 132 road freight or transport vehicle fire         132              22    22
# 133 - rail vehicle fire                            133               7     7
# 133 rail vehicle fire                              133               3     3
# 134 - water vehicle fire (boat, ship, etc.)        134              12    12
# 134 water vehicle fire                             134               3     3
# 135 - aircraft fire                                135               1     1
# 136 - self-propelled motor home or rv              136               2     2
# 136 self-propelled motor home or recreational v... 136               2     2
# 137 - camper or recreational vehicle (rv) fire     137               7     7
# 137 camper or recreational vehicle (rv) fire       137               9     9
# 138 - off-road vehicle or heavy equipment fire     138              12    12
# 138 off-road vehicle or heavy equipment fire       138               2     2
# 140 - natural vegetation fire, other               140             113   113
# 140 natural vegetation fire, other                 140              69    69
# 141 - forest, woods or wildland fire               141              14    14
# 141 forest, woods or wildland fire                 141              11    11
# 142 - brush, or brush and grass mixture fire       142             194   194
# 142 brush or brush-and-grass mixture fire          142              76    76
# 143 - grass fire                                   143             346   346
# 143 grass fire                                     143             111   111
# 150 - outside rubbish fire, other                  150            1702  1702
# 150 outside rubbish fire, other                    150            1012  1012
# 151 - outside rubbish, trash or waste fire         151            2709  2709
# 151 outside rubbish, trash or waste fire           151            1958  1958
# 152 - garbage dump or sanitary landfill fire       152               8     8
# 152 garbage dump or sanitary landfill fire         152               6     6
# 153 - construction or demolition landfill fire     153              10    10
# 153 construction or demolition landfill fire       153               3     3
# 154 - dumpster/outside trash receptacle fire       154            1084  1084
# 154 dumpster or other outside trash receptacle ... 154             435   435
# 155 - outside compactor/compacted trash fire       155              23    23
# 155 outside stationary compactor/compacted tras... 155              10    10
# 160 - special outside fire, other                  160             259   259
# 160 special outside fire, other                    160             260   260
# 1600 tent/encampment fire                          160               8     8
# 161 - outside storage fire                         161              24    24
# 161 outside storage fire                           161              13    13
# 162 - outside equipment fire                       162              72    72
# 162 outside equipment fire                         162              48    48
# 163 - outside gas/vapor combustion explosion       163              10    10
# 163 outside gas or vapor combustion explosion      163               2     2
# 164 - outside mailbox fire                         164              50    50
# 164 outside mailbox fire                           164              10    10
# 170 - cultivated vegetation, crop fire, other      170               6     6
# 170 cultivated vegetation, crop fire, other        170               5     5
# 173 - cultivated trees or nursery stock fire       173              24    24
# 173 cultivated trees or nursery stock fire         173               4     4
#
#                                                          Incident_Year
# Primary Situation                                  code
# 1 -                                                1 -              26
# 10 -                                               10               30
# 100 - fire, other                                  100             721
# 100 fire, other                                    100             823
# 11 -                                               11                2
# 111 - building fire                                111            3770
# 111 building fire                                  111             909
# 112 - fires in struct. other than in a bldg.       112             294
# 112 fires in structure other than in a building    112              58
# 113 - cooking fire, confined to container          113            9540
# 113 cooking fire, confined to container            113            2642
# 114 - chimney/flue fire, confined to chimney       114             132
# 114 chimney or flue fire, confined to chimney o... 114              28
# 115 - incinerator overload/mal.,fire confined      115              10
# 115 incinerator overload or malfunction, fire c... 115               4
# 116 - fuel burner/boiler mal., fire coinfined      116              28
# 116 fuel burner/boiler malfunction, fire confined  116               5
# 117 - commercial compactor fire, rubbish only      117              22
# 117 commercial compactor fire, confined to rubbish 117               1
# 118 - trash or rubbish fire, contained             118            6070
# 118 trash or rubbish fire, contained               118             585
# 120 - fire mob.prop. used as fixed structure       120               4
# 120 fire in mobile prop. used as a fixed struc.... 120               3
# 121 - fire in mob. home used as residence          121               4
# 121 fire in mobile home used as fixed residence    121               1
# 122 - fire in motor home, camper or rv             122              25
# 122 fire in motor home, camper, recreational ve... 122               3
# 123 - fire in portable bldg., fixed location       123              18
# 123 fire in portable building, fixed location      123               3
# 1230 fire in portable building (port-a-potty)      123              48
# 130 - mobile property (vehicle) fire, other        130             455
# 130 mobile property (vehicle) fire, other          130             103
# 131 - passenger vehicle fire                       131            1587
# 131 passenger vehicle fire                         131             521
# 132 - road freight or transport vehicle fire       132              38
# 132 road freight or transport vehicle fire         132              22
# 133 - rail vehicle fire                            133               7
# 133 rail vehicle fire                              133               3
# 134 - water vehicle fire (boat, ship, etc.)        134              12
# 134 water vehicle fire                             134               3
# 135 - aircraft fire                                135               1
# 136 - self-propelled motor home or rv              136               2
# 136 self-propelled motor home or recreational v... 136               2
# 137 - camper or recreational vehicle (rv) fire     137               7
# 137 camper or recreational vehicle (rv) fire       137               9
# 138 - off-road vehicle or heavy equipment fire     138              12
# 138 off-road vehicle or heavy equipment fire       138               2
# 140 - natural vegetation fire, other               140             113
# 140 natural vegetation fire, other                 140              69
# 141 - forest, woods or wildland fire               141              14
# 141 forest, woods or wildland fire                 141              11
# 142 - brush, or brush and grass mixture fire       142             194
# 142 brush or brush-and-grass mixture fire          142              76
# 143 - grass fire                                   143             346
# 143 grass fire                                     143             111
# 150 - outside rubbish fire, other                  150            1702
# 150 outside rubbish fire, other                    150            1012
# 151 - outside rubbish, trash or waste fire         151            2709
# 151 outside rubbish, trash or waste fire           151            1958
# 152 - garbage dump or sanitary landfill fire       152               8
# 152 garbage dump or sanitary landfill fire         152               6
# 153 - construction or demolition landfill fire     153              10
# 153 construction or demolition landfill fire       153               3
# 154 - dumpster/outside trash receptacle fire       154            1084
# 154 dumpster or other outside trash receptacle ... 154             435
# 155 - outside compactor/compacted trash fire       155              23
# 155 outside stationary compactor/compacted tras... 155              10
# 160 - special outside fire, other                  160             259
# 160 special outside fire, other                    160             260
# 1600 tent/encampment fire                          160               8
# 161 - outside storage fire                         161              24
# 161 outside storage fire                           161              13
# 162 - outside equipment fire                       162              72
# 162 outside equipment fire                         162              48
# 163 - outside gas/vapor combustion explosion       163              10
# 163 outside gas or vapor combustion explosion      163               2
# 164 - outside mailbox fire                         164              50
# 164 outside mailbox fire                           164              10
# 170 - cultivated vegetation, crop fire, other      170               6
# 170 cultivated vegetation, crop fire, other        170               5
# 173 - cultivated trees or nursery stock fire       173              24
# 173 cultivated trees or nursery stock fire         173               4

# %% [markdown]
# A bit difficult to make clear groupings, but I see the following:
#
# 1, 10, 11, 100, 112  "OTHER FIRE"
# 111                  "BUILDING FIRE"
# 113                  "COOKING FIRE"
# 114-118              "TRASH FIRE (INDOOR)"
# 120-138              "VEHICLE FIRE"
# 140-173              "OUTDOOR FIRE"
#
# Therefore, I implement as such.

# %%
di = {'FIRE OTHER': ['1 -', '10', '100', '11', '112'], 
      'BUILDING FIRE': ['111'], 
      'COOKING FIRE': ['113'], 
      'TRASH FIRE (INDOOR)': ['114','115','116','117','118'],
      'VEHICLE FIRE': ['120', '121', '122', '123', '130', '131', '132', '133', '134', '135', '136', '137', '138'],
      'OUTDOOR FIRE': ['140', '141', '142', '143', '150', '151', '152', '153', '154', '155', '160', '161', '162', '163', '164', '170', '173']}
# reverse the mapping
di = {d:c for c, d_list in di.items()
        for d in d_list}
#Map to 'Incident_Cat' groupings var
incident_df['Incident_Cat'] = incident_df['code'].map(di)

# %%
incident_df['Incident_Cat'].value_counts()
# Out:
# COOKING FIRE           12182
# OUTDOOR FIRE           10689
# TRASH FIRE (INDOOR)     6885
# BUILDING FIRE           4679
# VEHICLE FIRE            2895
# FIRE OTHER              1922
# Name: Incident_Cat, dtype: int64

# %% [markdown]
# ### Clean up and save data

# %%
incident_df['Incident_Dummy'] = 1
incident_df = incident_df[['Incident Date', 
                           'EAS', 
                           'Incident_Year', 
                           'Incident_Cat', 
                           'Incident_Dummy']]

# %%
incident_df.head()
# Out:
#   Incident Date       EAS  Incident_Year   Incident_Cat  Incident_Dummy
# 0    2015-06-20  451005.0           2015   COOKING FIRE               1
# 1    2006-08-05  422528.0           2006  BUILDING FIRE               1
# 2    2005-05-30  489180.0           2005   OUTDOOR FIRE               1
# 3    2010-11-28  360149.0           2010   COOKING FIRE               1
# 4    2003-10-05  279186.0           2003   OUTDOOR FIRE               1

# %%
#Export data
incident_df.to_csv(path_or_buf= path + '\\' + 'fireincident_data_formerge_20170917.csv', index=False)
