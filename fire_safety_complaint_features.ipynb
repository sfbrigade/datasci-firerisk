# %% [markdown]
# # Generating Fire Safety Complaint Features
# ## Introduction
# This notebook documents the process of generating feature data from the file `matched_Fire_Safety_Complaints.csv`

# %% [markdown]
# ## Loading the File

# %%
import pandas

PATH_TO_CSV = "./data/matched_Fire_Safety_Complaints.csv"
complaints = pandas.read_csv(PATH_TO_CSV)

# %% [markdown]
# ## Examining and Grouping the Complaint Item Types
# Using Python's `Counter`, accumulate all the types of complaints, and the number of each type, in this dadaset.

# %%
from collections import Counter

complaint_types = Counter(complaints["Complaint Item Type Description"])
complaint_types
# Out:
# Counter({nan: 2,
#          'sprinkler/standpipe systems': 995,
#          'combustible materials': 1456,
#          'uncategorized complaint': 9838,
#          'street numbering': 141,
#          'elevators not working': 217,
#          'weeds and grass': 634,
#          'exit maintenance': 147,
#          'ul cert verification': 445,
#          'extinguishers': 1611,
#          'roof access': 194,
#          'multiple fire code violations': 620,
#          'blocked exits': 3593,
#          'unlicensed auto repair': 116,
#          'electrical systems': 128,
#          'crisp complaint inspection': 32,
#          'operating without a permit': 577,
#          'refused hood + duct service': 49,
#          'unapproved place of assembly': 12,
#          'general hazardous materials': 343,
#          'alarm systems': 9683,
#          'fire escape': 122,
#          'hoarding': 108,
#          'open vacant building': 112,
#          'overcrowded place of assembly': 243,
#          'illegal occupancy': 37,
#          'leaking underground tanks': 4})

# %% [markdown]
# By looking at the total types, it seems that there are two complaints that have a type "nan", which appear to be complaints that weren't specified any type. We can drop these two.
# Several other complaint types seem to be more related to the safety of evacuation in case of fire (e.g. "blocked exits"), which are not related to the risk of fire happening. (We may drop these?)
# Furthermore, we may consider grouping similar complaint types.
# First, we may group many of the complaints into three categories: "potential fire cause", "potential fire control", and "fire emergency safety".
# * Potential Fire Cause:
#     * general hazardous materials
#     * leaking underground tanks
#     * hoarding
#     * combustible materials
#     * weeds and grass
#     * open vacant building
#     * refused hood + duct service
#     * electrical systems
#     * unlicensed auto repair
# * Potential Fire Control:
#     * alarm systems
#     * sprinkler/standpipe systems
#     * extinguishers
# * Fire Emergency Safety
#     * roof access
#     * unapproved place of assembly
#     * fire escape
#     * blocked exits
#     * exit maintenance
#     * street numbering
#     * overcrowded place of assembly
#
# In addition, I'm not exactly sure how to categorize the following complaint types:
# * ul cert verification
# * crisp complaint inspection
# * uncategorized complaint
# * multiple fire code violations
# * illegal occupancy
# * operating without a permit

# %% [markdown]
# ## The Disposition Column
#
# The possible values in this column can be acquired with the following step:

# %%
disposition_types = Counter(complaints["Disposition"])
disposition_types
# Out:
# Counter({nan: 2355,
#          'referred to another agency': 360,
#          'no jurisdiction': 199,
#          'violation issued': 5627,
#          'referred to pm inspection task force': 19,
#          'no access to building': 51,
#          'condition corrected': 17001,
#          'referred to dph': 12,
#          'duplicate complaint': 84,
#          'referred to dbi': 225,
#          'no merit': 5526})

# %% [markdown]
# There are 11 types of disposition values. The type 'no merit' and the type 'duplicate complaint' may indicate that the complaint is not valid, therefore we may ignore such complaints in the final output.
# There are also 2355 complaints where the disposition value is NaN. These complaints are preserved and counted towards the final output at this moment.

# %% [markdown]
# ## Generating Output
#
# First, define a few functions to check the values of each complaint:

# %%
from datetime import date

def is_valid_complaint(row):
    disposition = row["Disposition"]
    return not (disposition == "no merit" or disposition == "duplicate complaint")

def is_corrected(row):
    disposition = row["Disposition"]
    return disposition == "condition corrected"

def parse_date(date_str):
    """For a string in the format of YYYY-MM-DD, 
    return (YYYY, MM, DD)"""
    return tuple(map(int, date_str.split('-')))

def is_within_date_range(row, min_date_str, max_date_str):
    """checks if beg <= row["Received Date"] <= end
    row: a row in the dataset, representing one complaint
    min_date_str: a str representing the beginning of the date range
    max_date_str: a str representing the end of the date range
    """
    complaint_date = date(*parse_date(row["Received Date"]))
    min_date = date(*parse_date(min_date_str))
    max_date = date(*parse_date(max_date_str))
    
    return min_date <= complaint_date and max_date >= complaint_date

# %% [markdown]
# Next, define a mapping from a complaint description to a more general complaint category, following the previous observation.

# %%
# get the mappting from Complaint Item Type Description to Complaint Item Type
complaint_id_mapping = {}

for i, r in complaints.iterrows():
    dsc = r["Complaint Item Type Description"]
    complaint_id = r["Complaint Item Type"]
    if dsc in complaint_id_mapping:
        if complaint_id_mapping[dsc] != complaint_id:
            raise Exception("Complaint Type has different IDs")
    else:
        complaint_id_mapping[dsc] = complaint_id

complaint_id_mapping
# Out:
# {nan: 'unk',
#  'hoarding': '18',
#  'combustible materials': '10',
#  'overcrowded place of assembly': '11',
#  'general hazardous materials': '15',
#  'multiple fire code violations': '98',
#  'leaking underground tanks': '13',
#  'uncategorized complaint': '99',
#  'sprinkler/standpipe systems': '19',
#  'weeds and grass': '01',
#  'street numbering': '21',
#  'refused hood + duct service': '12',
#  'ul cert verification': '17',
#  'elevators not working': '09',
#  'roof access': '03',
#  'blocked exits': '02',
#  'open vacant building': '07',
#  'extinguishers': '06',
#  'electrical systems': '20',
#  'fire escape': '22',
#  'crisp complaint inspection': '16',
#  'unapproved place of assembly': '24',
#  'alarm systems': '05',
#  'operating without a permit': '08',
#  'unlicensed auto repair': '04',
#  'illegal occupancy': '25',
#  'exit maintenance': '23'}

# %%
# define mapping from complaint item type to category
potential_fire_cause = "potential fire cause"
potential_fire_control = "potential fire control"
fire_emergency_safety = "fire emergency safety"
multiple_violations = "multiple violations"

complaint_category_mapping = {"potential fire cause":['15', '13', '18', '10', '01', '07', '12', '20', '04'],
                              "potential fire control":['05', '19', '06'], 
                              "fire emergency safety": ['03', '24', '22', '02', '23', '21', '11']}
# reverse the mapping to get id -> category mappings
complaint_category_mapping = {d:c for c, d_list in complaint_category_mapping.items()
                                  for d in d_list}

# %% [markdown]
# Now, we're able to generate the output dataset.

# %%
from collections import defaultdict
from math import isnan

eas_to_features = defaultdict(lambda :defaultdict(float))

for d, r in complaints.iterrows():
    eas = r["EAS"]
    complaint_type = r["Complaint Item Type"]
    if not isnan(eas) and is_within_date_range(r, "2005-01-01", "2016-12-31"):
        features = eas_to_features[eas]
        # increment count features for generalized complaint types
        if complaint_type in complaint_category_mapping and is_valid_complaint(r):
            feature_name = "count {}".format(complaint_category_mapping[complaint_type])
            features[feature_name] += 1
        
            # increment count features for generalized complaint types not corrected:
            if not is_corrected(r):
                feature_name = "count {} not corrected".format(complaint_category_mapping[complaint_type])
                features[feature_name] += 1
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {458752.0: defaultdict(float, {}),
#              458755.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              360453.0: defaultdict(float, {}),
#              458758.0: defaultdict(float,
#                          {'count potential fire control': 4.0,
#                           'count potential fire control not corrected': 1.0}),
#              458761.0: defaultdict(float, {}),
#              458764.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              357670.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              426001.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              360468.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              458775.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              458784.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              458789.0: defaultdict(float, {}),
#              360495.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              458802.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              327731.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              458811.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0}),
#              360511.0: defaultdict(float, {}),
#              426055.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              278540.0: defaultdict(float,
#                          {'count fire emergency safety': 3.0,
#                           'count potential fire control': 1.0}),
#              360530.0: defaultdict(float, {}),
#              426068.0: defaultdict(float, {}),
#              426069.0: defaultdict(float, {}),
#              360536.0: defaultdict(float, {}),
#              295003.0: defaultdict(float, {}),
#              360542.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              393312.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              295015.0: defaultdict(float, {}),
#              458858.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 2.0}),
#              458860.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              369673.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              458865.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              295026.0: defaultdict(float, {}),
#              360563.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              278548.0: defaultdict(float, {}),
#              360579.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              360580.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              344086.0: defaultdict(float, {}),
#              360582.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              458887.0: defaultdict(float, {}),
#              426122.0: defaultdict(float,
#                          {'count potential fire control': 3.0,
#                           'count potential fire control not corrected': 2.0}),
#              458897.0: defaultdict(float, {}),
#              360596.0: defaultdict(float, {}),
#              426139.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              426148.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              458919.0: defaultdict(float, {}),
#              420551.0: defaultdict(float,
#                          {'count fire emergency safety': 5.0,
#                           'count potential fire cause': 1.0,
#                           'count potential fire control': 1.0}),
#              458924.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              458938.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              469706.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0}),
#              458945.0: defaultdict(float, {}),
#              458948.0: defaultdict(float, {}),
#              458951.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              295116.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              458963.0: defaultdict(float, {}),
#              426201.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              295131.0: defaultdict(float, {}),
#              426205.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              295136.0: defaultdict(float, {}),
#              458981.0: defaultdict(float, {}),
#              393446.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              426228.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              327929.0: defaultdict(float, {}),
#              295166.0: defaultdict(float, {}),
#              295171.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire cause': 1.0}),
#              295172.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              459015.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 4.0,
#                           'count potential fire control not corrected': 2.0}),
#              295176.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire control': 2.0}),
#              459023.0: defaultdict(float, {}),
#              295189.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 3.0}),
#              295191.0: defaultdict(float, {}),
#              295192.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459033.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459034.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              295201.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              459044.0: defaultdict(float, {}),
#              295207.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 4.0}),
#              360751.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              459059.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              295226.0: defaultdict(float,
#                          {'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 1.0}),
#              360768.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              295237.0: defaultdict(float, {}),
#              295240.0: defaultdict(float, {}),
#              459083.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              478174.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              442425.0: defaultdict(float, {}),
#              295256.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              459100.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              328029.0: defaultdict(float, {}),
#              456528.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              393567.0: defaultdict(float, {}),
#              295264.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              360803.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0,
#                           'count potential fire control': 1.0}),
#              328039.0: defaultdict(float, {}),
#              459119.0: defaultdict(float, {}),
#              295281.0: defaultdict(float, {}),
#              328054.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              459127.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459129.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              459131.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count potential fire control': 2.0}),
#              459137.0: defaultdict(float, {}),
#              393606.0: defaultdict(float, {}),
#              459151.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459160.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459163.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 6.0}),
#              459166.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              393635.0: defaultdict(float, {}),
#              459180.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459184.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire cause': 1.0,
#                           'count potential fire control': 5.0}),
#              459185.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459189.0: defaultdict(float, {}),
#              393655.0: defaultdict(float, {}),
#              459198.0: defaultdict(float, {}),
#              371446.0: defaultdict(float, {}),
#              295367.0: defaultdict(float, {}),
#              360906.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              436983.0: defaultdict(float, {}),
#              459226.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              393692.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              360926.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              393707.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              459246.0: defaultdict(float, {}),
#              360949.0: defaultdict(float, {}),
#              426489.0: defaultdict(float, {}),
#              393722.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              459259.0: defaultdict(float, {}),
#              458837.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              393733.0: defaultdict(float, {'count potential fire cause': 3.0}),
#              459273.0: defaultdict(float, {}),
#              295436.0: defaultdict(float, {}),
#              365997.0: defaultdict(float, {}),
#              486147.0: defaultdict(float, {}),
#              360980.0: defaultdict(float, {}),
#              459286.0: defaultdict(float, {}),
#              445618.0: defaultdict(float, {}),
#              459288.0: defaultdict(float, {}),
#              459290.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              328221.0: defaultdict(float, {}),
#              360999.0: defaultdict(float,
#                          {'count potential fire control': 5.0,
#                           'count potential fire control not corrected': 2.0}),
#              426538.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              426541.0: defaultdict(float, {}),
#              328239.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              459316.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              426561.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361033.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              361036.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              426574.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              426576.0: defaultdict(float, {}),
#              459346.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361046.0: defaultdict(float, {}),
#              361050.0: defaultdict(float, {}),
#              459357.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              295519.0: defaultdict(float, {}),
#              459361.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              426596.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              295527.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              314266.0: defaultdict(float, {}),
#              295535.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459379.0: defaultdict(float, {}),
#              361080.0: defaultdict(float, {}),
#              295548.0: defaultdict(float, {}),
#              459391.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361089.0: defaultdict(float,
#                          {'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 1.0}),
#              459396.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              361096.0: defaultdict(float, {}),
#              361103.0: defaultdict(float, {}),
#              426645.0: defaultdict(float, {}),
#              295578.0: defaultdict(float, {}),
#              459419.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 3.0}),
#              360095.0: defaultdict(float, {}),
#              459424.0: defaultdict(float, {}),
#              459425.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              459426.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 10.0,
#                           'count potential fire control not corrected': 1.0}),
#              459440.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459441.0: defaultdict(float, {}),
#              459442.0: defaultdict(float,
#                          {'count potential fire control': 5.0,
#                           'count potential fire control not corrected': 1.0}),
#              426678.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              295608.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count potential fire control': 1.0}),
#              361146.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              361148.0: defaultdict(float,
#                          {'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 1.0}),
#              459456.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              295618.0: defaultdict(float,
#                          {'count fire emergency safety': 4.0,
#                           'count potential fire control': 3.0}),
#              361156.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              459461.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              459468.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361167.0: defaultdict(float, {}),
#              361169.0: defaultdict(float, {}),
#              459481.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              426715.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              459484.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              361181.0: defaultdict(float, {}),
#              459492.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire cause': 2.0,
#                           'count potential fire cause not corrected': 1.0,
#                           'count potential fire control': 5.0,
#                           'count potential fire control not corrected': 2.0}),
#              426729.0: defaultdict(float, {}),
#              359639.0: defaultdict(float,
#                          {'count potential fire control': 4.0}),
#              361212.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count fire emergency safety not corrected': 2.0,
#                           'count potential fire control': 3.0}),
#              459521.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              459524.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361223.0: defaultdict(float, {}),
#              426760.0: defaultdict(float, {}),
#              459529.0: defaultdict(float,
#                          {'count potential fire control': 4.0}),
#              295698.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              426115.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459541.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459554.0: defaultdict(float, {}),
#              295716.0: defaultdict(float, {}),
#              361255.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              295720.0: defaultdict(float, {}),
#              361257.0: defaultdict(float,
#                          {'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 1.0}),
#              360583.0: defaultdict(float, {}),
#              295725.0: defaultdict(float, {}),
#              361263.0: defaultdict(float, {}),
#              295728.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              361267.0: defaultdict(float, {}),
#              295733.0: defaultdict(float, {}),
#              295737.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361275.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              361279.0: defaultdict(float, {}),
#              459585.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              361285.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              376972.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              459596.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459597.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              361294.0: defaultdict(float, {}),
#              361295.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              295760.0: defaultdict(float, {}),
#              295762.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459603.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              459607.0: defaultdict(float, {}),
#              394072.0: defaultdict(float, {}),
#              295769.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459611.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 2.0}),
#              459616.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              295780.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              361321.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459626.0: defaultdict(float,
#                          {'count potential fire control': 11.0}),
#              426859.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361330.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              295797.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 2.0}),
#              282632.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361335.0: defaultdict(float, {}),
#              295801.0: defaultdict(float,
#                          {'count potential fire control': 5.0}),
#              295802.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count potential fire control': 1.0}),
#              295803.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              295804.0: defaultdict(float, {}),
#              295807.0: defaultdict(float, {}),
#              295808.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              453440.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459650.0: defaultdict(float, {}),
#              295811.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459652.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              295813.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              459660.0: defaultdict(float, {}),
#              361357.0: defaultdict(float, {}),
#              459662.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              295825.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              295826.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              295827.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 2.0}),
#              295828.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459671.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              295832.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 1.0}),
#              295833.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              295834.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              459678.0: defaultdict(float, {}),
#              361376.0: defaultdict(float, {}),
#              361379.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              459685.0: defaultdict(float, {}),
#              426919.0: defaultdict(float,
#                          {'count potential fire control': 5.0}),
#              475292.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              295850.0: defaultdict(float,
#                          {'count potential fire control': 4.0}),
#              394165.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              295866.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              295876.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              459723.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              295885.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459728.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              442531.0: defaultdict(float, {}),
#              361430.0: defaultdict(float, {}),
#              361434.0: defaultdict(float, {}),
#              459739.0: defaultdict(float, {}),
#              295900.0: defaultdict(float, {}),
#              295901.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              459742.0: defaultdict(float, {}),
#              295904.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              426982.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361448.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              300540.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 1.0}),
#              361450.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              361453.0: defaultdict(float, {}),
#              295918.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              295919.0: defaultdict(float, {}),
#              295922.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              295924.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              295925.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 7.0}),
#              295926.0: defaultdict(float, {'count potential fire cause': 2.0}),
#              295927.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              459768.0: defaultdict(float,
#                          {'count fire emergency safety': 5.0,
#                           'count potential fire cause': 1.0,
#                           'count potential fire control': 1.0}),
#              295934.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              328703.0: defaultdict(float, {}),
#              486231.0: defaultdict(float, {}),
#              392811.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              295952.0: defaultdict(float, {}),
#              295954.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              295955.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              295956.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              295957.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              459804.0: defaultdict(float, {}),
#              453945.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              295966.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              349701.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              404315.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              459814.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              415240.0: defaultdict(float, {}),
#              459830.0: defaultdict(float, {}),
#              295991.0: defaultdict(float, {}),
#              361529.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              361530.0: defaultdict(float, {}),
#              296000.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361539.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire control': 1.0}),
#              296005.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              328775.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              459848.0: defaultdict(float, {}),
#              361549.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count fire emergency safety not corrected': 2.0,
#                           'count potential fire control': 3.0,
#                           'count potential fire control not corrected': 1.0}),
#              361551.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              459858.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              296019.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              358332.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire cause': 1.0,
#                           'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 2.0}),
#              296026.0: defaultdict(float, {}),
#              361563.0: defaultdict(float, {}),
#              296031.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459874.0: defaultdict(float, {}),
#              459884.0: defaultdict(float, {}),
#              328813.0: defaultdict(float, {}),
#              296046.0: defaultdict(float,
#                          {'count potential fire control': 3.0,
#                           'count potential fire control not corrected': 1.0}),
#              459892.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459902.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 2.0}),
#              459907.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              459911.0: defaultdict(float, {}),
#              459915.0: defaultdict(float, {}),
#              361612.0: defaultdict(float,
#                          {'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 1.0}),
#              361626.0: defaultdict(float, {}),
#              296091.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              459939.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              459943.0: defaultdict(float, {}),
#              459951.0: defaultdict(float, {}),
#              394423.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              284191.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire control': 1.0}),
#              459964.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              459970.0: defaultdict(float, {}),
#              459973.0: defaultdict(float, {}),
#              361676.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 3.0,
#                           'count potential fire control not corrected': 1.0}),
#              427213.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              361679.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              459984.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              296145.0: defaultdict(float,
#                          {'count potential fire control': 5.0}),
#              361682.0: defaultdict(float, {}),
#              459989.0: defaultdict(float, {}),
#              459990.0: defaultdict(float, {}),
#              459992.0: defaultdict(float, {}),
#              361691.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 1.0}),
#              296156.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              427239.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              445136.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              460015.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              361716.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              361724.0: defaultdict(float, {}),
#              361725.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              394496.0: defaultdict(float, {}),
#              448043.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              311510.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 1.0}),
#              460038.0: defaultdict(float, {}),
#              296200.0: defaultdict(float,
#                          {'count potential fire control': 3.0,
#                           'count potential fire control not corrected': 1.0}),
#              460041.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              296202.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              361740.0: defaultdict(float, {}),
#              361741.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0,
#                           'count potential fire control': 1.0}),
#              361742.0: defaultdict(float,
#                          {'count potential fire control': 4.0}),
#              460053.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              460057.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              296218.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              296221.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              296224.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              460067.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count fire emergency safety not corrected': 2.0}),
#              460073.0: defaultdict(float, {}),
#              427306.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              394539.0: defaultdict(float, {}),
#              460077.0: defaultdict(float, {}),
#              394544.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire cause': 1.0,
#                           'count potential fire control': 1.0}),
#              316979.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count potential fire control': 2.0}),
#              460086.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              460089.0: defaultdict(float,
#                          {'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 2.0}),
#              329019.0: defaultdict(float, {}),
#              427328.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              460102.0: defaultdict(float, {}),
#              394570.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              460109.0: defaultdict(float,
#                          {'count potential fire control': 5.0}),
#              460110.0: defaultdict(float,
#                          {'count potential fire control': 4.0,
#                           'count potential fire control not corrected': 1.0}),
#              486285.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 2.0}),
#              361808.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              394579.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              282648.0: defaultdict(float, {}),
#              460126.0: defaultdict(float, {'count potential fire cause': 3.0}),
#              486288.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              394604.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              296301.0: defaultdict(float, {}),
#              460146.0: defaultdict(float, {}),
#              296310.0: defaultdict(float,
#                          {'count potential fire control': 3.0,
#                           'count potential fire control not corrected': 1.0}),
#              296311.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              431679.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              427390.0: defaultdict(float, {}),
#              288105.0: defaultdict(float, {}),
#              460163.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              285003.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              296331.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              460175.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              427408.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 1.0}),
#              427410.0: defaultdict(float, {}),
#              460183.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              427419.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              296350.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 3.0,
#                           'count potential fire control not corrected': 2.0}),
#              460199.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              415303.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              460206.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              460212.0: defaultdict(float, {}),
#              460213.0: defaultdict(float, {}),
#              460215.0: defaultdict(float, {}),
#              458996.0: defaultdict(float, {}),
#              460218.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              460243.0: defaultdict(float, {}),
#              460245.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 1.0}),
#              460246.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              329175.0: defaultdict(float, {}),
#              460248.0: defaultdict(float, {}),
#              460254.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              460256.0: defaultdict(float, {}),
#              460258.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              460260.0: defaultdict(float, {}),
#              394725.0: defaultdict(float, {}),
#              296423.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              359032.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              460268.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire cause': 1.0,
#                           'count potential fire control': 2.0}),
#              278781.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              460273.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              486313.0: defaultdict(float,
#                          {'count potential fire control': 5.0}),
#              394755.0: defaultdict(float, {}),
#              296452.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              361990.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              427535.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              296466.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count potential fire cause': 1.0,
#                           'count potential fire control': 1.0}),
#              296467.0: defaultdict(float, {}),
#              296468.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              296469.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              404400.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
# ...
#                          {'count fire emergency safety': 2.0}),
#              461665.0: defaultdict(float, {}),
#              396130.0: defaultdict(float, {}),
#              464699.0: defaultdict(float, {}),
#              297831.0: defaultdict(float, {}),
#              360170.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              461677.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire control': 4.0,
#                           'count potential fire control not corrected': 2.0}),
#              297838.0: defaultdict(float,
#                          {'count potential fire control': 5.0}),
#              363394.0: defaultdict(float, {}),
#              461703.0: defaultdict(float, {}),
#              428936.0: defaultdict(float, {}),
#              461711.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              442862.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              428954.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              330658.0: defaultdict(float, {}),
#              396200.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              281611.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              461748.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              297909.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              297912.0: defaultdict(float, {}),
#              442868.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count potential fire control': 1.0}),
#              297925.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 2.0}),
#              297930.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              297931.0: defaultdict(float, {}),
#              461774.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              429011.0: defaultdict(float, {}),
#              363478.0: defaultdict(float, {'count potential fire cause': 2.0}),
#              429024.0: defaultdict(float, {}),
#              429027.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              429030.0: defaultdict(float, {}),
#              461806.0: defaultdict(float,
#                          {'count potential fire cause': 2.0,
#                           'count potential fire cause not corrected': 2.0}),
#              461812.0: defaultdict(float, {}),
#              393727.0: defaultdict(float, {}),
#              297986.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              429059.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              366422.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              396294.0: defaultdict(float, {}),
#              297991.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              429066.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              461835.0: defaultdict(float, {}),
#              461836.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              429081.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              330779.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              330780.0: defaultdict(float, {}),
#              429087.0: defaultdict(float, {}),
#              461857.0: defaultdict(float, {}),
#              330786.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              363555.0: defaultdict(float, {}),
#              298020.0: defaultdict(float, {}),
#              298021.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              429094.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              461866.0: defaultdict(float, {}),
#              298027.0: defaultdict(float, {}),
#              461870.0: defaultdict(float,
#                          {'count fire emergency safety': 3.0,
#                           'count potential fire control': 4.0}),
#              288162.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire control': 4.0,
#                           'count potential fire control not corrected': 2.0}),
#              429109.0: defaultdict(float, {}),
#              298040.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              298041.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              461882.0: defaultdict(float, {}),
#              461886.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              298056.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              298069.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 3.0}),
#              298073.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              410127.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              464741.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              461924.0: defaultdict(float, {}),
#              429159.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              461933.0: defaultdict(float, {}),
#              429167.0: defaultdict(float, {}),
#              396400.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              298097.0: defaultdict(float, {}),
#              464745.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count potential fire cause': 1.0,
#                           'count potential fire control': 6.0}),
#              363640.0: defaultdict(float, {}),
#              429182.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire cause': 2.0}),
#              363653.0: defaultdict(float,
#                          {'count potential fire control': 3.0,
#                           'count potential fire control not corrected': 1.0}),
#              461963.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              298124.0: defaultdict(float, {}),
#              298126.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              298130.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              363668.0: defaultdict(float,
#                          {'count fire emergency safety': 3.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire control': 1.0}),
#              461973.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              461977.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              298148.0: defaultdict(float, {}),
#              298157.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              363697.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire cause not corrected': 1.0}),
#              330931.0: defaultdict(float, {}),
#              275073.0: defaultdict(float,
#                          {'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 2.0}),
#              429241.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              462012.0: defaultdict(float, {}),
#              429252.0: defaultdict(float, {}),
#              298190.0: defaultdict(float,
#                          {'count potential fire control': 3.0}),
#              298191.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              462033.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 6.0}),
#              330970.0: defaultdict(float, {}),
#              363740.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              298210.0: defaultdict(float, {}),
#              298212.0: defaultdict(float, {}),
#              462054.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              287077.0: defaultdict(float, {}),
#              462058.0: defaultdict(float, {}),
#              429291.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              462060.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              298221.0: defaultdict(float,
#                          {'count potential fire control': 4.0}),
#              298227.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              363766.0: defaultdict(float, {}),
#              298232.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              462077.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              462080.0: defaultdict(float,
#                          {'count potential fire control': 4.0}),
#              462083.0: defaultdict(float,
#                          {'count potential fire cause': 1.0,
#                           'count potential fire control': 2.0}),
#              462089.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              462090.0: defaultdict(float, {}),
#              462099.0: defaultdict(float,
#                          {'count potential fire control': 9.0}),
#              363798.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              388313.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              462105.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              363803.0: defaultdict(float, {'count potential fire cause': 1.0}),
#              363806.0: defaultdict(float, {}),
#              363809.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              298275.0: defaultdict(float,
#                          {'count potential fire control': 2.0,
#                           'count potential fire control not corrected': 1.0}),
#              298276.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire control': 1.0}),
#              363816.0: defaultdict(float, {}),
#              298281.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              363819.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              429359.0: defaultdict(float, {}),
#              298288.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              429363.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0}),
#              481644.0: defaultdict(float, {}),
#              429368.0: defaultdict(float, {}),
#              363833.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0}),
#              453855.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              298300.0: defaultdict(float, {}),
#              399242.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              298305.0: defaultdict(float, {}),
#              399243.0: defaultdict(float,
#                          {'count potential fire control': 1.0,
#                           'count potential fire control not corrected': 1.0}),
#              298309.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              448474.0: defaultdict(float, {}),
#              331083.0: defaultdict(float, {'count potential fire cause': 2.0}),
#              462163.0: defaultdict(float, {}),
#              462166.0: defaultdict(float,
#                          {'count potential fire control': 2.0}),
#              429406.0: defaultdict(float, {}),
#              363871.0: defaultdict(float,
#                          {'count fire emergency safety': 2.0,
#                           'count fire emergency safety not corrected': 1.0,
#                           'count potential fire cause': 1.0}),
#              462177.0: defaultdict(float,
#                          {'count potential fire control': 3.0,
#                           'count potential fire control not corrected': 1.0}),
#              363876.0: defaultdict(float, {}),
#              363882.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count fire emergency safety not corrected': 1.0}),
#              363889.0: defaultdict(float, {}),
#              429427.0: defaultdict(float, {}),
#              363892.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 1.0}),
#              363893.0: defaultdict(float, {}),
#              363894.0: defaultdict(float,
#                          {'count potential fire control': 5.0,
#                           'count potential fire control not corrected': 3.0}),
#              462205.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              298369.0: defaultdict(float,
#                          {'count fire emergency safety': 1.0,
#                           'count potential fire control': 2.0}),
#              462210.0: defaultdict(float,
#                          {'count potential fire control': 7.0,
#                           'count potential fire control not corrected': 1.0}),
#              363907.0: defaultdict(float, {}),
#              462212.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              366486.0: defaultdict(float,
#                          {'count potential fire control': 1.0}),
#              ...})
